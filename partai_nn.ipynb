# %% [markdown]
# ## **Importing requirements**

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
import torchaudio
import sys

import IPython.display as ipd

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ## **Dataset class**

# %%
import os
from torch.utils.data import Dataset

class AudioDataset(Dataset):
    def __init__(self, root_dir):
        self.root_dir = root_dir
        self.classes = sorted(os.listdir(root_dir))

        self.audio_files = []
        self.labels = []

        # Iterate over each class directory
        for i, cls in enumerate(self.classes):
            class_dir = os.path.join(root_dir, cls)
            class_label = os.path.basename(class_dir)
            file_names = os.listdir(class_dir)

            # Load each audio file and assign label
            for file_name in file_names:
                file_path = os.path.join(class_dir, file_name)
                self.audio_files.append(file_path)
                self.labels.append(class_label)

    def __len__(self):
        return len(self.audio_files)

    def __getitem__(self, idx):
        file_path = self.audio_files[idx]
        label = self.labels[idx]

        waveform, sample_rate = torchaudio.load(file_path)

        # You can apply preprocessing to the waveform here if needed
        # For example: waveform = preprocess_audio(waveform)

        return waveform, sample_rate, label

# %% [markdown]
# ## **Using google drive as a file explorer for google colab**

# %%
# Detect whether notebook runs in google colab
if "google.colab" in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    root_drive_path = '/content/drive/My Drive/12words'
else:
    root_drive_path = '12words'

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# root_drive_path = '/content/drive/My Drive/12words'

# Define the root directory of your dataset
root_dir = root_drive_path

# Create an instance of AudioDataset
dataset = AudioDataset(root_dir)
display(dataset.classes)
# Out:
# ['1', '11', '13', '15', '17', '19', '3', '4', '5', '7', '8', '9']

# %% [markdown]
# ## **Spliting dataset to create Train_set and Test_set**

# %%
from torch.utils.data import Dataset, DataLoader, random_split

test_size = int(0.05 * len(dataset))  # 5% of the dataset for validation
train_size = len(dataset) - test_size

# Split the dataset into training and validation sets
train_set, test_set = random_split(dataset, [train_size, test_size])

print(f'train set size: {len(train_set)}')
print(f'test set size: {len(test_set)}')
# Out:
# train set size: 456
# test set size: 24

# %% [markdown]
# ## **Checking one data from train_set**

# %%
# train_set[0]
waveform_first, sample_rate, _ = train_set[0]
display(ipd.Audio(waveform_first.numpy(), rate=sample_rate))
display(waveform_first)
display(waveform_first.shape)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 3.0951e-08, 1.0477e-08,
#          4.5316e-09]])
# torch.Size([1, 63360])

# %% [markdown]
# ## **Transforms**

# %%
new_sample_rate = 8000
transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=new_sample_rate)
transformed = transform(waveform_first)

display(ipd.Audio(transformed.numpy(), rate=new_sample_rate))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## **Label to index and vice versa**

# %%
labels = sorted(list(set(datapoint[2] for datapoint in train_set)))
display(labels)
# Out:
# ['1', '11', '13', '15', '17', '19', '3', '4', '5', '7', '8', '9']

# %%
def label_to_index(word):
    # Return the position of the word in labels
    return torch.tensor(labels.index(word))


def index_to_label(index):
    # Return the word corresponding to the index in labels
    # This is the inverse of label_to_index
    return labels[index]

# %% [markdown]
# ## **Using Train_set and Test_set to create Train_loader and Test_loader**

# %%
def pad_sequence(batch):
    # Make all tensor in a batch the same length by padding with zeros

    # item.t() = transpose of the item.
    # before:[length, features] --> after:[features, length]
    batch = [item.t() for item in batch]

    # output shape: [batch_size, max_length_dim, feature_dim]
    # batch_first --> batch dimension should be the first dimension.
    batch = torch.nn.utils.rnn.pad_sequence(batch, batch_first=True, padding_value=0.)

    # changing second and third dim with premute(0,2,1):
    # output shape: [batch_size, feature_dim, max_length_dim]
    # assuming that all waveform having same length of T(max) after padding:
    # output shape: [[0,1,...,31], [0 (1 channel)], [0,1,...,T(max)]]
    return batch.permute(0, 2, 1)    


# input: list of (audio, label)
# input: a batch comming from train/test_set
# =============================================================
# output: one tuple: (batched audios, batched labels)
# output: a batch for train/test_loader (ready to train/test)
def collate_fn(batch):
    # A data tuple has the form:
    # waveform, sample_rate, label

    tensors, targets = [], []

    # Gather in lists, and encode labels as indices
    for waveform, _, label in batch:
        tensors += [waveform]
        targets += [label_to_index(label)]

    # Group the list of tensors into a batched tensor
    tensors = pad_sequence(tensors)
    targets = torch.stack(targets)

    # tensors.shape --> [batch_size, feature_dim (channels), max_length_dim]
    # tensors are ready for learning. (1 'tensors' = 1 ready-to-train batch)
    return tensors, targets


batch_size = 32

if device == "cuda":
    num_workers = 1
    pin_memory = True
else:
    num_workers = 0
    pin_memory = False

train_loader = torch.utils.data.DataLoader(
    train_set,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory,
)
test_loader = torch.utils.data.DataLoader(
    test_set,
    batch_size=batch_size,
    shuffle=False,
    drop_last=False,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory,
)

# %% [markdown]
# ## **The CNN model**

# %%
class M5(nn.Module):
    def __init__(self, n_input=1, n_output=12, stride=16, n_channel=32):
        super().__init__()
        self.conv1 = nn.Conv1d(n_input, n_channel, kernel_size=80, stride=stride)
        self.bn1 = nn.BatchNorm1d(n_channel)
        self.pool1 = nn.MaxPool1d(4)
        self.conv2 = nn.Conv1d(n_channel, n_channel, kernel_size=3)
        self.bn2 = nn.BatchNorm1d(n_channel)
        self.pool2 = nn.MaxPool1d(4)
        self.conv3 = nn.Conv1d(n_channel, 2 * n_channel, kernel_size=3)
        self.bn3 = nn.BatchNorm1d(2 * n_channel)
        self.pool3 = nn.MaxPool1d(4)
        self.conv4 = nn.Conv1d(2 * n_channel, 2 * n_channel, kernel_size=3)
        self.bn4 = nn.BatchNorm1d(2 * n_channel)
        self.pool4 = nn.MaxPool1d(4)
        self.fc1 = nn.Linear(2 * n_channel, n_output)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(self.bn1(x))
        x = self.pool1(x)
        x = self.conv2(x)
        x = F.relu(self.bn2(x))
        x = self.pool2(x)
        x = self.conv3(x)
        x = F.relu(self.bn3(x))
        x = self.pool3(x)
        x = self.conv4(x)
        x = F.relu(self.bn4(x))
        x = self.pool4(x)
        x = F.avg_pool1d(x, x.shape[-1])
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        return F.log_softmax(x, dim=2)


# n_input = number of channels = 1
model = M5(n_input=transformed.shape[0], n_output=len(labels))
model.to(device)
print(model)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

n = count_parameters(model)
print("Number of parameters: %s" % n)
# Out:
# M5(
#   (conv1): Conv1d(1, 32, kernel_size=(80,), stride=(16,))
#   (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(32, 32, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv1d(32, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool3): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv1d(64, 64, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool4): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=64, out_features=12, bias=True)
# )
# Number of parameters: 25420

# %%
optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=0.0001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)  # reduce the learning after 20 epochs by a factor of 10

# %% [markdown]
# ## **Train function**

# %%
def train(model, epoch, log_interval):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data = data.to(device)
        target = target.to(device)

        # apply transform and model on whole batch directly on device
        data = transform(data)
        output = model(data)

        # negative log-likelihood for a tensor of size (batch x 1 x n_output)
        loss = F.nll_loss(output.squeeze(), target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # print training stats
        if batch_idx % log_interval == 0:
            print(f"Train Epoch.batch: {epoch}.{batch_idx} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item():.6f}")

        # record loss
        losses.append(loss.item())

# %% [markdown]
# ## **Test function**

# %%
def number_of_correct(pred, target):
    # count number of correct predictions
    return pred.squeeze().eq(target).sum().item()


def get_likely_index(tensor):
    # find most likely label index for each element in the batch
    return tensor.argmax(dim=-1)


def test(model, epoch):
    model.eval()
    correct = 0
    for data, target in test_loader:

        data = data.to(device)
        target = target.to(device)

        # apply transform and model on whole batch directly on device
        data = transform(data)
        output = model(data)

        pred = get_likely_index(output)
        correct += number_of_correct(pred, target)


    print(f"\nTest Epoch: {epoch}\tAccuracy: {correct}/{len(test_loader.dataset)} ({100. * correct / len(test_loader.dataset):.0f}%)\n")

# %% [markdown]
# ## **Training the model and showing the test results**

# %%
log_interval = 5
n_epoch = 100

losses = []

# The transform needs to live on the same device as the model and the data.
transform = transform.to(device)

for epoch in range(1, n_epoch + 1):
    train(model, epoch, log_interval)
    test(model, epoch)
    scheduler.step()
# Out:
# Train Epoch.batch: 1.0 [0/456 (0%)]	Loss: 2.558689
# Train Epoch.batch: 1.5 [160/456 (33%)]	Loss: 2.549321
# Train Epoch.batch: 1.10 [320/456 (67%)]	Loss: 2.472692
#
# Test Epoch: 1	Accuracy: 0/24 (0%)
#
# Train Epoch.batch: 2.0 [0/456 (0%)]	Loss: 2.424859
# Train Epoch.batch: 2.5 [160/456 (33%)]	Loss: 2.171338
# Train Epoch.batch: 2.10 [320/456 (67%)]	Loss: 2.161887
#
# Test Epoch: 2	Accuracy: 3/24 (12%)
#
# Train Epoch.batch: 3.0 [0/456 (0%)]	Loss: 2.213490
# Train Epoch.batch: 3.5 [160/456 (33%)]	Loss: 2.066067
# Train Epoch.batch: 3.10 [320/456 (67%)]	Loss: 2.142511
#
# Test Epoch: 3	Accuracy: 6/24 (25%)
#
# Train Epoch.batch: 4.0 [0/456 (0%)]	Loss: 1.708125
# Train Epoch.batch: 4.5 [160/456 (33%)]	Loss: 2.005044
# Train Epoch.batch: 4.10 [320/456 (67%)]	Loss: 1.930602
#
# Test Epoch: 4	Accuracy: 8/24 (33%)
#
# Train Epoch.batch: 5.0 [0/456 (0%)]	Loss: 1.820579
# Train Epoch.batch: 5.5 [160/456 (33%)]	Loss: 1.814924
# Train Epoch.batch: 5.10 [320/456 (67%)]	Loss: 1.784848
#
# Test Epoch: 5	Accuracy: 6/24 (25%)
#
# Train Epoch.batch: 6.0 [0/456 (0%)]	Loss: 1.459639
# Train Epoch.batch: 6.5 [160/456 (33%)]	Loss: 1.491759
# Train Epoch.batch: 6.10 [320/456 (67%)]	Loss: 1.595629
#
# Test Epoch: 6	Accuracy: 4/24 (17%)
#
# Train Epoch.batch: 7.0 [0/456 (0%)]	Loss: 1.336484
# Train Epoch.batch: 7.5 [160/456 (33%)]	Loss: 1.140115
# Train Epoch.batch: 7.10 [320/456 (67%)]	Loss: 1.444653
#
# Test Epoch: 7	Accuracy: 9/24 (38%)
#
# Train Epoch.batch: 8.0 [0/456 (0%)]	Loss: 1.346803
# Train Epoch.batch: 8.5 [160/456 (33%)]	Loss: 1.364132
# Train Epoch.batch: 8.10 [320/456 (67%)]	Loss: 1.321173
#
# Test Epoch: 8	Accuracy: 11/24 (46%)
#
# Train Epoch.batch: 9.0 [0/456 (0%)]	Loss: 1.140207
# Train Epoch.batch: 9.5 [160/456 (33%)]	Loss: 1.250311
# Train Epoch.batch: 9.10 [320/456 (67%)]	Loss: 1.225041
#
# Test Epoch: 9	Accuracy: 9/24 (38%)
#
# Train Epoch.batch: 10.0 [0/456 (0%)]	Loss: 0.909544
# Train Epoch.batch: 10.5 [160/456 (33%)]	Loss: 1.085267
# Train Epoch.batch: 10.10 [320/456 (67%)]	Loss: 0.714147
#
# Test Epoch: 10	Accuracy: 7/24 (29%)
#
# Train Epoch.batch: 11.0 [0/456 (0%)]	Loss: 0.798705
# Train Epoch.batch: 11.5 [160/456 (33%)]	Loss: 0.963813
# Train Epoch.batch: 11.10 [320/456 (67%)]	Loss: 1.143906
#
# Test Epoch: 11	Accuracy: 13/24 (54%)
#
# Train Epoch.batch: 12.0 [0/456 (0%)]	Loss: 1.131821
# Train Epoch.batch: 12.5 [160/456 (33%)]	Loss: 0.919254
# Train Epoch.batch: 12.10 [320/456 (67%)]	Loss: 0.754415
#
# Test Epoch: 12	Accuracy: 8/24 (33%)
#
# Train Epoch.batch: 13.0 [0/456 (0%)]	Loss: 0.708564
# Train Epoch.batch: 13.5 [160/456 (33%)]	Loss: 0.861682
# Train Epoch.batch: 13.10 [320/456 (67%)]	Loss: 0.817903
#
# Test Epoch: 13	Accuracy: 11/24 (46%)
#
# Train Epoch.batch: 14.0 [0/456 (0%)]	Loss: 0.749750
# Train Epoch.batch: 14.5 [160/456 (33%)]	Loss: 0.597746
# Train Epoch.batch: 14.10 [320/456 (67%)]	Loss: 0.458610
#
# Test Epoch: 14	Accuracy: 14/24 (58%)
#
# Train Epoch.batch: 15.0 [0/456 (0%)]	Loss: 0.494183
# Train Epoch.batch: 15.5 [160/456 (33%)]	Loss: 0.773241
# Train Epoch.batch: 15.10 [320/456 (67%)]	Loss: 0.561430
#
# Test Epoch: 15	Accuracy: 9/24 (38%)
#
# Train Epoch.batch: 16.0 [0/456 (0%)]	Loss: 0.216950
# Train Epoch.batch: 16.5 [160/456 (33%)]	Loss: 0.414255
# Train Epoch.batch: 16.10 [320/456 (67%)]	Loss: 0.338835
#
# Test Epoch: 16	Accuracy: 14/24 (58%)
#
# Train Epoch.batch: 17.0 [0/456 (0%)]	Loss: 0.449056
# Train Epoch.batch: 17.5 [160/456 (33%)]	Loss: 0.487958
# Train Epoch.batch: 17.10 [320/456 (67%)]	Loss: 0.565153
#
# Test Epoch: 17	Accuracy: 10/24 (42%)
#
# Train Epoch.batch: 18.0 [0/456 (0%)]	Loss: 0.360813
# Train Epoch.batch: 18.5 [160/456 (33%)]	Loss: 0.564609
# Train Epoch.batch: 18.10 [320/456 (67%)]	Loss: 0.555527
#
# Test Epoch: 18	Accuracy: 10/24 (42%)
#
# Train Epoch.batch: 19.0 [0/456 (0%)]	Loss: 0.527078
# Train Epoch.batch: 19.5 [160/456 (33%)]	Loss: 0.609056
# Train Epoch.batch: 19.10 [320/456 (67%)]	Loss: 0.252114
#
# Test Epoch: 19	Accuracy: 16/24 (67%)
#
# Train Epoch.batch: 20.0 [0/456 (0%)]	Loss: 0.354934
# Train Epoch.batch: 20.5 [160/456 (33%)]	Loss: 0.763659
# Train Epoch.batch: 20.10 [320/456 (67%)]	Loss: 0.756691
#
# Test Epoch: 20	Accuracy: 13/24 (54%)
#
# Train Epoch.batch: 21.0 [0/456 (0%)]	Loss: 0.459467
# Train Epoch.batch: 21.5 [160/456 (33%)]	Loss: 0.337900
# Train Epoch.batch: 21.10 [320/456 (67%)]	Loss: 0.178662
#
# Test Epoch: 21	Accuracy: 19/24 (79%)
#
# Train Epoch.batch: 22.0 [0/456 (0%)]	Loss: 0.170293
# Train Epoch.batch: 22.5 [160/456 (33%)]	Loss: 0.275021
# Train Epoch.batch: 22.10 [320/456 (67%)]	Loss: 0.212960
#
# Test Epoch: 22	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 23.0 [0/456 (0%)]	Loss: 0.200822
# Train Epoch.batch: 23.5 [160/456 (33%)]	Loss: 0.179823
# Train Epoch.batch: 23.10 [320/456 (67%)]	Loss: 0.194760
#
# Test Epoch: 23	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 24.0 [0/456 (0%)]	Loss: 0.165837
# Train Epoch.batch: 24.5 [160/456 (33%)]	Loss: 0.369231
# Train Epoch.batch: 24.10 [320/456 (67%)]	Loss: 0.294978
#
# Test Epoch: 24	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 25.0 [0/456 (0%)]	Loss: 0.197197
# Train Epoch.batch: 25.5 [160/456 (33%)]	Loss: 0.205251
# Train Epoch.batch: 25.10 [320/456 (67%)]	Loss: 0.344258
#
# Test Epoch: 25	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 26.0 [0/456 (0%)]	Loss: 0.167059
# Train Epoch.batch: 26.5 [160/456 (33%)]	Loss: 0.211624
# Train Epoch.batch: 26.10 [320/456 (67%)]	Loss: 0.166864
#
# Test Epoch: 26	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 27.0 [0/456 (0%)]	Loss: 0.162167
# Train Epoch.batch: 27.5 [160/456 (33%)]	Loss: 0.235956
# Train Epoch.batch: 27.10 [320/456 (67%)]	Loss: 0.263569
#
# Test Epoch: 27	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 28.0 [0/456 (0%)]	Loss: 0.164990
# Train Epoch.batch: 28.5 [160/456 (33%)]	Loss: 0.204958
# Train Epoch.batch: 28.10 [320/456 (67%)]	Loss: 0.234093
#
# Test Epoch: 28	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 29.0 [0/456 (0%)]	Loss: 0.132521
# Train Epoch.batch: 29.5 [160/456 (33%)]	Loss: 0.146543
# Train Epoch.batch: 29.10 [320/456 (67%)]	Loss: 0.164968
#
# Test Epoch: 29	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 30.0 [0/456 (0%)]	Loss: 0.130441
# Train Epoch.batch: 30.5 [160/456 (33%)]	Loss: 0.237333
# Train Epoch.batch: 30.10 [320/456 (67%)]	Loss: 0.139455
#
# Test Epoch: 30	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 31.0 [0/456 (0%)]	Loss: 0.177178
# Train Epoch.batch: 31.5 [160/456 (33%)]	Loss: 0.154672
# Train Epoch.batch: 31.10 [320/456 (67%)]	Loss: 0.094305
#
# Test Epoch: 31	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 32.0 [0/456 (0%)]	Loss: 0.199180
# Train Epoch.batch: 32.5 [160/456 (33%)]	Loss: 0.153135
# Train Epoch.batch: 32.10 [320/456 (67%)]	Loss: 0.132809
#
# Test Epoch: 32	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 33.0 [0/456 (0%)]	Loss: 0.158858
# Train Epoch.batch: 33.5 [160/456 (33%)]	Loss: 0.450692
# Train Epoch.batch: 33.10 [320/456 (67%)]	Loss: 0.119674
#
# Test Epoch: 33	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 34.0 [0/456 (0%)]	Loss: 0.208025
# Train Epoch.batch: 34.5 [160/456 (33%)]	Loss: 0.155067
# Train Epoch.batch: 34.10 [320/456 (67%)]	Loss: 0.122997
#
# Test Epoch: 34	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 35.0 [0/456 (0%)]	Loss: 0.211224
# Train Epoch.batch: 35.5 [160/456 (33%)]	Loss: 0.072000
# Train Epoch.batch: 35.10 [320/456 (67%)]	Loss: 0.172500
#
# Test Epoch: 35	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 36.0 [0/456 (0%)]	Loss: 0.153599
# Train Epoch.batch: 36.5 [160/456 (33%)]	Loss: 0.098214
# Train Epoch.batch: 36.10 [320/456 (67%)]	Loss: 0.099312
#
# Test Epoch: 36	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 37.0 [0/456 (0%)]	Loss: 0.143269
# Train Epoch.batch: 37.5 [160/456 (33%)]	Loss: 0.077878
# Train Epoch.batch: 37.10 [320/456 (67%)]	Loss: 0.196200
#
# Test Epoch: 37	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 38.0 [0/456 (0%)]	Loss: 0.313779
# Train Epoch.batch: 38.5 [160/456 (33%)]	Loss: 0.078974
# Train Epoch.batch: 38.10 [320/456 (67%)]	Loss: 0.139587
#
# Test Epoch: 38	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 39.0 [0/456 (0%)]	Loss: 0.102419
# Train Epoch.batch: 39.5 [160/456 (33%)]	Loss: 0.206723
# Train Epoch.batch: 39.10 [320/456 (67%)]	Loss: 0.110433
#
# Test Epoch: 39	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 40.0 [0/456 (0%)]	Loss: 0.103800
# Train Epoch.batch: 40.5 [160/456 (33%)]	Loss: 0.115168
# Train Epoch.batch: 40.10 [320/456 (67%)]	Loss: 0.177489
#
# Test Epoch: 40	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 41.0 [0/456 (0%)]	Loss: 0.139683
# Train Epoch.batch: 41.5 [160/456 (33%)]	Loss: 0.090263
# Train Epoch.batch: 41.10 [320/456 (67%)]	Loss: 0.162852
#
# Test Epoch: 41	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 42.0 [0/456 (0%)]	Loss: 0.132085
# Train Epoch.batch: 42.5 [160/456 (33%)]	Loss: 0.065663
# Train Epoch.batch: 42.10 [320/456 (67%)]	Loss: 0.119850
#
# Test Epoch: 42	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 43.0 [0/456 (0%)]	Loss: 0.147118
# Train Epoch.batch: 43.5 [160/456 (33%)]	Loss: 0.058172
# Train Epoch.batch: 43.10 [320/456 (67%)]	Loss: 0.057260
#
# Test Epoch: 43	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 44.0 [0/456 (0%)]	Loss: 0.085775
# Train Epoch.batch: 44.5 [160/456 (33%)]	Loss: 0.137125
# Train Epoch.batch: 44.10 [320/456 (67%)]	Loss: 0.109545
#
# Test Epoch: 44	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 45.0 [0/456 (0%)]	Loss: 0.048934
# Train Epoch.batch: 45.5 [160/456 (33%)]	Loss: 0.085158
# Train Epoch.batch: 45.10 [320/456 (67%)]	Loss: 0.081436
#
# Test Epoch: 45	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 46.0 [0/456 (0%)]	Loss: 0.228921
# Train Epoch.batch: 46.5 [160/456 (33%)]	Loss: 0.215854
# Train Epoch.batch: 46.10 [320/456 (67%)]	Loss: 0.107381
#
# Test Epoch: 46	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 47.0 [0/456 (0%)]	Loss: 0.094547
# Train Epoch.batch: 47.5 [160/456 (33%)]	Loss: 0.138134
# Train Epoch.batch: 47.10 [320/456 (67%)]	Loss: 0.131364
#
# Test Epoch: 47	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 48.0 [0/456 (0%)]	Loss: 0.102040
# Train Epoch.batch: 48.5 [160/456 (33%)]	Loss: 0.211787
# Train Epoch.batch: 48.10 [320/456 (67%)]	Loss: 0.069025
#
# Test Epoch: 48	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 49.0 [0/456 (0%)]	Loss: 0.197110
# Train Epoch.batch: 49.5 [160/456 (33%)]	Loss: 0.066952
# Train Epoch.batch: 49.10 [320/456 (67%)]	Loss: 0.058709
#
# Test Epoch: 49	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 50.0 [0/456 (0%)]	Loss: 0.094180
# Train Epoch.batch: 50.5 [160/456 (33%)]	Loss: 0.197362
# Train Epoch.batch: 50.10 [320/456 (67%)]	Loss: 0.068525
#
# Test Epoch: 50	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 51.0 [0/456 (0%)]	Loss: 0.156749
# Train Epoch.batch: 51.5 [160/456 (33%)]	Loss: 0.068283
# Train Epoch.batch: 51.10 [320/456 (67%)]	Loss: 0.161133
#
# Test Epoch: 51	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 52.0 [0/456 (0%)]	Loss: 0.073340
# Train Epoch.batch: 52.5 [160/456 (33%)]	Loss: 0.114531
# Train Epoch.batch: 52.10 [320/456 (67%)]	Loss: 0.098551
#
# Test Epoch: 52	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 53.0 [0/456 (0%)]	Loss: 0.184064
# Train Epoch.batch: 53.5 [160/456 (33%)]	Loss: 0.069169
# Train Epoch.batch: 53.10 [320/456 (67%)]	Loss: 0.135499
#
# Test Epoch: 53	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 54.0 [0/456 (0%)]	Loss: 0.082186
# Train Epoch.batch: 54.5 [160/456 (33%)]	Loss: 0.073124
# Train Epoch.batch: 54.10 [320/456 (67%)]	Loss: 0.097819
#
# Test Epoch: 54	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 55.0 [0/456 (0%)]	Loss: 0.118582
# Train Epoch.batch: 55.5 [160/456 (33%)]	Loss: 0.130863
# Train Epoch.batch: 55.10 [320/456 (67%)]	Loss: 0.060509
#
# Test Epoch: 55	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 56.0 [0/456 (0%)]	Loss: 0.098790
# Train Epoch.batch: 56.5 [160/456 (33%)]	Loss: 0.109597
# Train Epoch.batch: 56.10 [320/456 (67%)]	Loss: 0.214321
#
# Test Epoch: 56	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 57.0 [0/456 (0%)]	Loss: 0.091193
# Train Epoch.batch: 57.5 [160/456 (33%)]	Loss: 0.134602
# Train Epoch.batch: 57.10 [320/456 (67%)]	Loss: 0.080355
#
# Test Epoch: 57	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 58.0 [0/456 (0%)]	Loss: 0.085161
# Train Epoch.batch: 58.5 [160/456 (33%)]	Loss: 0.083062
# Train Epoch.batch: 58.10 [320/456 (67%)]	Loss: 0.149911
#
# Test Epoch: 58	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 59.0 [0/456 (0%)]	Loss: 0.110858
# Train Epoch.batch: 59.5 [160/456 (33%)]	Loss: 0.094389
# Train Epoch.batch: 59.10 [320/456 (67%)]	Loss: 0.102414
#
# Test Epoch: 59	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 60.0 [0/456 (0%)]	Loss: 0.153642
# Train Epoch.batch: 60.5 [160/456 (33%)]	Loss: 0.067406
# Train Epoch.batch: 60.10 [320/456 (67%)]	Loss: 0.047133
#
# Test Epoch: 60	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 61.0 [0/456 (0%)]	Loss: 0.062489
# Train Epoch.batch: 61.5 [160/456 (33%)]	Loss: 0.198686
# Train Epoch.batch: 61.10 [320/456 (67%)]	Loss: 0.101963
#
# Test Epoch: 61	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 62.0 [0/456 (0%)]	Loss: 0.158222
# Train Epoch.batch: 62.5 [160/456 (33%)]	Loss: 0.106235
# Train Epoch.batch: 62.10 [320/456 (67%)]	Loss: 0.197928
#
# Test Epoch: 62	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 63.0 [0/456 (0%)]	Loss: 0.093509
# Train Epoch.batch: 63.5 [160/456 (33%)]	Loss: 0.054459
# Train Epoch.batch: 63.10 [320/456 (67%)]	Loss: 0.063955
#
# Test Epoch: 63	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 64.0 [0/456 (0%)]	Loss: 0.171212
# Train Epoch.batch: 64.5 [160/456 (33%)]	Loss: 0.079222
# Train Epoch.batch: 64.10 [320/456 (67%)]	Loss: 0.098502
#
# Test Epoch: 64	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 65.0 [0/456 (0%)]	Loss: 0.071954
# Train Epoch.batch: 65.5 [160/456 (33%)]	Loss: 0.190649
# Train Epoch.batch: 65.10 [320/456 (67%)]	Loss: 0.100865
#
# Test Epoch: 65	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 66.0 [0/456 (0%)]	Loss: 0.077827
# Train Epoch.batch: 66.5 [160/456 (33%)]	Loss: 0.075105
# Train Epoch.batch: 66.10 [320/456 (67%)]	Loss: 0.106804
#
# Test Epoch: 66	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 67.0 [0/456 (0%)]	Loss: 0.053280
# Train Epoch.batch: 67.5 [160/456 (33%)]	Loss: 0.128156
# Train Epoch.batch: 67.10 [320/456 (67%)]	Loss: 0.161750
#
# Test Epoch: 67	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 68.0 [0/456 (0%)]	Loss: 0.107737
# Train Epoch.batch: 68.5 [160/456 (33%)]	Loss: 0.085226
# Train Epoch.batch: 68.10 [320/456 (67%)]	Loss: 0.122481
#
# Test Epoch: 68	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 69.0 [0/456 (0%)]	Loss: 0.103310
# Train Epoch.batch: 69.5 [160/456 (33%)]	Loss: 0.110000
# Train Epoch.batch: 69.10 [320/456 (67%)]	Loss: 0.136518
#
# Test Epoch: 69	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 70.0 [0/456 (0%)]	Loss: 0.073986
# Train Epoch.batch: 70.5 [160/456 (33%)]	Loss: 0.085721
# Train Epoch.batch: 70.10 [320/456 (67%)]	Loss: 0.080092
#
# Test Epoch: 70	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 71.0 [0/456 (0%)]	Loss: 0.134895
# Train Epoch.batch: 71.5 [160/456 (33%)]	Loss: 0.123937
# Train Epoch.batch: 71.10 [320/456 (67%)]	Loss: 0.152351
#
# Test Epoch: 71	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 72.0 [0/456 (0%)]	Loss: 0.119385
# Train Epoch.batch: 72.5 [160/456 (33%)]	Loss: 0.097395
# Train Epoch.batch: 72.10 [320/456 (67%)]	Loss: 0.145195
#
# Test Epoch: 72	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 73.0 [0/456 (0%)]	Loss: 0.093392
# Train Epoch.batch: 73.5 [160/456 (33%)]	Loss: 0.078873
# Train Epoch.batch: 73.10 [320/456 (67%)]	Loss: 0.075133
#
# Test Epoch: 73	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 74.0 [0/456 (0%)]	Loss: 0.065207
# Train Epoch.batch: 74.5 [160/456 (33%)]	Loss: 0.150355
# Train Epoch.batch: 74.10 [320/456 (67%)]	Loss: 0.056522
#
# Test Epoch: 74	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 75.0 [0/456 (0%)]	Loss: 0.201855
# Train Epoch.batch: 75.5 [160/456 (33%)]	Loss: 0.111796
# Train Epoch.batch: 75.10 [320/456 (67%)]	Loss: 0.102799
#
# Test Epoch: 75	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 76.0 [0/456 (0%)]	Loss: 0.088938
# Train Epoch.batch: 76.5 [160/456 (33%)]	Loss: 0.152019
# Train Epoch.batch: 76.10 [320/456 (67%)]	Loss: 0.118752
#
# Test Epoch: 76	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 77.0 [0/456 (0%)]	Loss: 0.105977
# Train Epoch.batch: 77.5 [160/456 (33%)]	Loss: 0.188908
# Train Epoch.batch: 77.10 [320/456 (67%)]	Loss: 0.116680
#
# Test Epoch: 77	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 78.0 [0/456 (0%)]	Loss: 0.089556
# Train Epoch.batch: 78.5 [160/456 (33%)]	Loss: 0.090982
# Train Epoch.batch: 78.10 [320/456 (67%)]	Loss: 0.160388
#
# Test Epoch: 78	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 79.0 [0/456 (0%)]	Loss: 0.153274
# Train Epoch.batch: 79.5 [160/456 (33%)]	Loss: 0.176862
# Train Epoch.batch: 79.10 [320/456 (67%)]	Loss: 0.109203
#
# Test Epoch: 79	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 80.0 [0/456 (0%)]	Loss: 0.053099
# Train Epoch.batch: 80.5 [160/456 (33%)]	Loss: 0.093095
# Train Epoch.batch: 80.10 [320/456 (67%)]	Loss: 0.061134
#
# Test Epoch: 80	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 81.0 [0/456 (0%)]	Loss: 0.055726
# Train Epoch.batch: 81.5 [160/456 (33%)]	Loss: 0.108726
# Train Epoch.batch: 81.10 [320/456 (67%)]	Loss: 0.222146
#
# Test Epoch: 81	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 82.0 [0/456 (0%)]	Loss: 0.096827
# Train Epoch.batch: 82.5 [160/456 (33%)]	Loss: 0.156807
# Train Epoch.batch: 82.10 [320/456 (67%)]	Loss: 0.042082
#
# Test Epoch: 82	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 83.0 [0/456 (0%)]	Loss: 0.105382
# Train Epoch.batch: 83.5 [160/456 (33%)]	Loss: 0.073493
# Train Epoch.batch: 83.10 [320/456 (67%)]	Loss: 0.130882
#
# Test Epoch: 83	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 84.0 [0/456 (0%)]	Loss: 0.059752
# Train Epoch.batch: 84.5 [160/456 (33%)]	Loss: 0.230855
# Train Epoch.batch: 84.10 [320/456 (67%)]	Loss: 0.085378
#
# Test Epoch: 84	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 85.0 [0/456 (0%)]	Loss: 0.107724
# Train Epoch.batch: 85.5 [160/456 (33%)]	Loss: 0.083215
# Train Epoch.batch: 85.10 [320/456 (67%)]	Loss: 0.081145
#
# Test Epoch: 85	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 86.0 [0/456 (0%)]	Loss: 0.166398
# Train Epoch.batch: 86.5 [160/456 (33%)]	Loss: 0.096425
# Train Epoch.batch: 86.10 [320/456 (67%)]	Loss: 0.058131
#
# Test Epoch: 86	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 87.0 [0/456 (0%)]	Loss: 0.085097
# Train Epoch.batch: 87.5 [160/456 (33%)]	Loss: 0.309318
# Train Epoch.batch: 87.10 [320/456 (67%)]	Loss: 0.171391
#
# Test Epoch: 87	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 88.0 [0/456 (0%)]	Loss: 0.080966
# Train Epoch.batch: 88.5 [160/456 (33%)]	Loss: 0.069980
# Train Epoch.batch: 88.10 [320/456 (67%)]	Loss: 0.075851
#
# Test Epoch: 88	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 89.0 [0/456 (0%)]	Loss: 0.071172
# Train Epoch.batch: 89.5 [160/456 (33%)]	Loss: 0.145910
# Train Epoch.batch: 89.10 [320/456 (67%)]	Loss: 0.114557
#
# Test Epoch: 89	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 90.0 [0/456 (0%)]	Loss: 0.193500
# Train Epoch.batch: 90.5 [160/456 (33%)]	Loss: 0.088035
# Train Epoch.batch: 90.10 [320/456 (67%)]	Loss: 0.173130
#
# Test Epoch: 90	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 91.0 [0/456 (0%)]	Loss: 0.129466
# Train Epoch.batch: 91.5 [160/456 (33%)]	Loss: 0.058153
# Train Epoch.batch: 91.10 [320/456 (67%)]	Loss: 0.099952
#
# Test Epoch: 91	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 92.0 [0/456 (0%)]	Loss: 0.198521
# Train Epoch.batch: 92.5 [160/456 (33%)]	Loss: 0.094742
# Train Epoch.batch: 92.10 [320/456 (67%)]	Loss: 0.124761
#
# Test Epoch: 92	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 93.0 [0/456 (0%)]	Loss: 0.135797
# Train Epoch.batch: 93.5 [160/456 (33%)]	Loss: 0.212754
# Train Epoch.batch: 93.10 [320/456 (67%)]	Loss: 0.125172
#
# Test Epoch: 93	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 94.0 [0/456 (0%)]	Loss: 0.120491
# Train Epoch.batch: 94.5 [160/456 (33%)]	Loss: 0.096930
# Train Epoch.batch: 94.10 [320/456 (67%)]	Loss: 0.157703
#
# Test Epoch: 94	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 95.0 [0/456 (0%)]	Loss: 0.082177
# Train Epoch.batch: 95.5 [160/456 (33%)]	Loss: 0.050771
# Train Epoch.batch: 95.10 [320/456 (67%)]	Loss: 0.129715
#
# Test Epoch: 95	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 96.0 [0/456 (0%)]	Loss: 0.053713
# Train Epoch.batch: 96.5 [160/456 (33%)]	Loss: 0.086296
# Train Epoch.batch: 96.10 [320/456 (67%)]	Loss: 0.090149
#
# Test Epoch: 96	Accuracy: 21/24 (88%)
#
# Train Epoch.batch: 97.0 [0/456 (0%)]	Loss: 0.111807
# Train Epoch.batch: 97.5 [160/456 (33%)]	Loss: 0.101379
# Train Epoch.batch: 97.10 [320/456 (67%)]	Loss: 0.049155
#
# Test Epoch: 97	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 98.0 [0/456 (0%)]	Loss: 0.098595
# Train Epoch.batch: 98.5 [160/456 (33%)]	Loss: 0.076246
# Train Epoch.batch: 98.10 [320/456 (67%)]	Loss: 0.066570
#
# Test Epoch: 98	Accuracy: 20/24 (83%)
#
# Train Epoch.batch: 99.0 [0/456 (0%)]	Loss: 0.086677
# Train Epoch.batch: 99.5 [160/456 (33%)]	Loss: 0.094960
# Train Epoch.batch: 99.10 [320/456 (67%)]	Loss: 0.069381
#
# Test Epoch: 99	Accuracy: 22/24 (92%)
#
# Train Epoch.batch: 100.0 [0/456 (0%)]	Loss: 0.057220
# Train Epoch.batch: 100.5 [160/456 (33%)]	Loss: 0.137210
# Train Epoch.batch: 100.10 [320/456 (67%)]	Loss: 0.099197
#
# Test Epoch: 100	Accuracy: 22/24 (92%)

# %% [markdown]
# ## **Saving the model**

# %%
MODEL_STATE_PATH = 'model_state.pt'
torch.save(model.state_dict(), MODEL_STATE_PATH)

MODEL_PATH = 'model.pt'
torch.save(model, MODEL_PATH)

# %% [markdown]
# ## **Prediction using trained model**

# %%
def predict(tensor):
    # Use the model to predict the label of the waveform
    tensor = tensor.to(device)
    tensor = transform(tensor)
    tensor = model(tensor.unsqueeze(0))
    tensor = get_likely_index(tensor)
    tensor = index_to_label(tensor.squeeze())
    return tensor


waveform, sample_rate, label = train_set[-1]
ipd.Audio(waveform.numpy(), rate=sample_rate)

print(f"Expected: {label}. Predicted: {predict(waveform)}.")
# Out:
# Expected: 9. Predicted: 9.

# %% [markdown]
# ## **Finding an example that isn't classified correctly**

# %%
for i, (waveform, sample_rate, utterance, *_) in enumerate(test_set):
    output = predict(waveform)
    if output != utterance:
        display(ipd.Audio(waveform.numpy(), rate=sample_rate))
        print(f"Data point #{i}. Expected: {utterance}. Predicted: {output}.")
        break
else:
    print("All examples in this dataset were correctly classified!")
    print("In this case, let's just look at the last data point")
    display(ipd.Audio(waveform.numpy(), rate=sample_rate))
    print(f"Data point #{i}. Expected: {utterance}. Predicted: {output}.")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Data point #0. Expected: 3. Predicted: 13.
